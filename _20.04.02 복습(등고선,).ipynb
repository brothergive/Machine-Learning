# %%
# 등고선 그리기

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.arange(-1,1,0.1)
y=np.arange(-1,1,0.1)

X,Y=np.meshgrid(x,y)
Z=np.sin(X*Y)

CS=plt.contour(X,Y,Z,levels=np.arange(-1,1,0.2))
plt.clabel(CS,inline=2,fontsize=10)
plt.colorbar()

# %%
x=np.arange(-1,1,0.1)
y=np.arange(-1,1,0.1)

X,Y=np.meshgrid(x,y)
Z=np.exp(-(X**2+Y**2))

plt.contourf(X,Y,Z,levels=np.arange(-1,1,0.05),alpha=0.5,cmap='seismic')
plt.colorbar()


CS=plt.contour(X,Y,Z,levels=np.arange(-1,1,0.05))
plt.clabel(CS,inline=2,fontsize=10)
# Out:
# <a list of 23 text.Text objects>

# %%
#subplot 그리는 2가지 방법

fig,axes=plt.subplots(2,2,figsize=[10,8])

axes[0,0].plot([1,2,3,4])
axes[0,1].scatter(np.random.randn(100),np.random.randn(100))
axes[1,0].bar(range(10),range(10))
axes[1,1].imshow(np.random.randn(64,64))

fig.suptitle('Test',fontsize=20)
axes[0,0].set_title('Test1')
# Out:
# Text(0.5, 1.0, 'Test1')

# %%
plt.subplot(2,2,1)
plt.plot([1,2,3,4])

plt.subplot(2,2,2)
plt.scatter(np.random.randn(100),np.random.randn(100))

plt.subplot(2,2,3)
plt.bar(range(10),range(10))

plt.subplot(2,2,4)
plt.imshow(np.random.randn(64,64))

# %%
#화살표 그리기
plt.axis([-10,10,-10,10])
plt.vlines([0,5,-5],-10,10,linestyles=':') # 수직으로 점(0,5,-5)에 -10에서 10까지 그려라
plt.hlines([0,5,-5],-10,10,linestyles=':') # ([그리는 좌표],길이,선 스타일)
plt.text(0,0,'hello',fontsize=20,va='top',ha='right') # 글 쓰기

# 화살표
plt.annotate('zero',xy=(0,0),xytext=(5,5),arrowprops=dict(facecolor='black')) 
# (문자,xy=화살표 방향, xytext=문자,화살표 위치,arrowprops=화살표 성격)
# Out:
# Text(5, 5, 'zero')

# %%
#플롯 저장하기

# %%
#x,y 축 다루기 : equal,off
plt.plot(range(5))
plt.axis('off')
# Out:
# (-0.2, 4.2, -0.2, 4.2)

# %%
plt.plot(range(5),range(10,20,2))

# %%
#확률 밀도 함수 p376

# %%
# 필터 적용

# %%
# 사이즈 축소 풀링

# %%
#sql 파일 파싱 (가급적 판다스로 읽고 넘파이로 변경!)
